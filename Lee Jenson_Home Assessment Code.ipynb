# %%
import string
import math
import random

# %%
## Location data = (lat, long)
DEPOT_LOC = (4.4184,114.0932)

# List to store customer info 
CUSTOMERS = []
# List to store vehicle info
VEHICLES = []

# %%
# Define Helper Functions

def get_customer_info(id):
    return CUSTOMERS[id-1]

def cal_distance(loc1, loc2):
    return 100 * math.sqrt((loc2[1] - loc1[1])**2 + (loc2[0] - loc1[0])**2)

def add_customer_info(lat, long, demand):
    new_cus_id = len(CUSTOMERS) + 1
    new_cus_info = {'id':new_cus_id,
                    'loc':(lat,long),
                    'demand':demand}
    return CUSTOMERS.append(new_cus_info)

def add_vehicle_info(capacity, cost):
    uppercase_alphabet = string.ascii_uppercase
    new_vehicle_type = uppercase_alphabet[len(VEHICLES)]
    new_vehicle_info = {'type': new_vehicle_type,
                        'capacity':capacity,
                        'cost per km':cost}
    return VEHICLES.append(new_vehicle_info)

def get_vehicle_info(type):
    curr_vehicle_idx = string.ascii_uppercase.index(type)
    return VEHICLES[curr_vehicle_idx]

# %%
# Add Customers

add_customer_info(4.3555,113.9777,5)
add_customer_info(4.3976,114.0049,8)
add_customer_info(4.3163,114.0764,3)
add_customer_info(4.3184,113.9932,6)
add_customer_info(4.4024,113.9896,5)
add_customer_info(4.4142,114.0127,8)
add_customer_info(4.4804,114.0734,3)
add_customer_info(4.3818,114.2034,6)
add_customer_info(4.4935,114.1928,5)
add_customer_info(4.4932,114.1322,8)

CUSTOMERS
# Out:
# [{'id': 1, 'loc': (4.3555, 113.9777), 'demand': 5},
#  {'id': 2, 'loc': (4.3976, 114.0049), 'demand': 8},
#  {'id': 3, 'loc': (4.3163, 114.0764), 'demand': 3},
#  {'id': 4, 'loc': (4.3184, 113.9932), 'demand': 6},
#  {'id': 5, 'loc': (4.4024, 113.9896), 'demand': 5},
#  {'id': 6, 'loc': (4.4142, 114.0127), 'demand': 8},
#  {'id': 7, 'loc': (4.4804, 114.0734), 'demand': 3},
#  {'id': 8, 'loc': (4.3818, 114.2034), 'demand': 6},
#  {'id': 9, 'loc': (4.4935, 114.1928), 'demand': 5},
#  {'id': 10, 'loc': (4.4932, 114.1322), 'demand': 8}]

# %%
# Add Vehicles

add_vehicle_info(25,1.2)
add_vehicle_info(30,1.5)
add_vehicle_info(27,1.3)

VEHICLES
# Out:
# [{'type': 'A', 'capacity': 25, 'cost per km': 1.2},
#  {'type': 'B', 'capacity': 30, 'cost per km': 1.5},
#  {'type': 'C', 'capacity': 27, 'cost per km': 1.3}]

# %%
# Vehicle object constructor 

class Vehicle():
    def __init__(self, name, capacity, mileage_cost, route, starting_loc):
        self.name = name
        self.capacity = capacity
        self.mileage_cost = mileage_cost
        self.route = route
        self.starting_loc = starting_loc

        self.calculate()

    def __str__(self):
        return str({
            'type':self.name,
            'route':self.route
        })

    def calculate(self):
        total_demand = 0
        total_distance = 0

        curr_loc = self.starting_loc
        for customer_id in self.route:
            next_customer = get_customer_info(customer_id) 
            # calculate demand
            total_demand += next_customer['demand']

            # calculate distance
            total_distance += cal_distance(curr_loc,next_customer['loc'])

            curr_customer = next_customer
            curr_loc = curr_customer['loc']

        total_distance += cal_distance(curr_loc,self.starting_loc)
        total_cost = self.mileage_cost * total_distance

        # set mandatory properties with new values
        self.distance = total_distance
        self.cost = total_cost
        self.demand = total_demand

        if self.overloaded():
            self.cost += 10000 # bias value

    def overloaded(self):
        return self.demand > self.capacity
    
    def distance_list(self):
        distance_list = []
        curr_loc = self.starting_loc
        for customer_id in self.route:
            next_customer = get_customer_info(customer_id) 

            distance_list.append(cal_distance(curr_loc,next_customer['loc']))

            curr_customer = next_customer
            curr_loc = curr_customer['loc']

        distance_list.append(cal_distance(curr_loc,self.starting_loc))

        return distance_list

# %%
# Soltuion object constructor (base solution)

class Solution():
    def __init__(self, vehicles):
        self.vehicles = vehicles

    def __str__(self):
        return str([{
            'type':vehicle.name,
            'route':vehicle.route
            } for vehicle in self.vehicles])

    def fitness(self):
        total_fitness = 0 # fitness = cost
    
        for vehicle in self.vehicles:
            total_fitness += vehicle.cost

        return total_fitness
    
    # for override
    def mate(self, solution2):
        pass

    def cal_distance(self):
        total_distance = 0

        for vehicle in self.vehicles:
            total_distance += vehicle.distance

        return total_distance

    def print(self):

        
        print(f"Total Distance: {self.cal_distance():.2f}KM")
        print(f"Total cost: RM{self.fitness():.2f}")
        print("\n")

        for vehicle in self.vehicles:
            print(f"Vehicle {vehicle.name}:")
            print(f"Round Trip Distance: {vehicle.distance:.2f} KM, Cost: RM{vehicle.cost:.2f}, Demand: {vehicle.demand}, Capacity: {vehicle.capacity}")
            
            distance_list = vehicle.distance_list()
            vehicle_route = vehicle.route
            route_segments = [f"Depot"]

            for i in range(len(vehicle.route)):
                route_segments.append(f"{vehicle_route[i]} ({distance_list[i]:.2f} KM)")
            
            route_segments.append(f"Depot ({distance_list[len(distance_list)-1]:.2f} KM)")
            route_str = " -> ".join(route_segments)

            print(route_str)
            print('\n')

# %%
# Solution 1 (inherit Solution)

class Solution1(Solution):
    def mutate(vehicle):
        start, end = sorted(random.sample(range(10), 2))
        sublist = vehicle.route[start:end]
        random.shuffle(sublist)
        vehicle.route[start:end] = sublist
        vehicle.calculate()

    def generate_child_sol(vehicles, inherit_vehicle):
        vehicles_list = []

        curr_idx = 0
        for vehicle in vehicles:
            if curr_idx == inherit_vehicle: vehicles_list.append(vehicle)
            else:
                mutated_vehicle = Vehicle(
                    vehicle.name,
                    vehicle.capacity,
                    vehicle.mileage_cost,
                    vehicle.route.copy(),
                    vehicle.starting_loc
                )
                Solution1.mutate(mutated_vehicle)

                vehicles_list.append(mutated_vehicle)

        return Solution1(vehicles_list)
    
    def mate(self, solution2):
        prob = random.random()
        # Crossover (cross gene exchange, e.g split ratio and routes)

        if prob < 0.45: 
            inherit_vehicle = random.randint(0,len(VEHICLES)-1)
        
            return Solution1.generate_child_sol(self.vehicles,inherit_vehicle)
    
        elif prob < 0.90: 
            inherit_vehicle = random.randint(0,len(VEHICLES)-1)
        
            return Solution1.generate_child_sol(solution2.vehicles,inherit_vehicle)
        else:
        # Mutation (Self gene exchange)
            vehicle_choice = random.choice([self, solution2])
            return Solution1.generate_child_sol(vehicle_choice.vehicles,-1) # -1 to mutate every vehicle

# %%
# Solution 2 (inherit Solution)

class Solution2(Solution):
    def get_split_ratio(vehicles):
        split_portion = []
        for vehicle in vehicles:
            split_portion.append(len(vehicle.route))
        return split_portion

    def create_child_sol(split_ratio,combined_route):
        vehicle_type = [vehicle['type'] for vehicle in VEHICLES]

        vehicles = []

        curr_idx = 0
        for type in vehicle_type:
            curr_vehicle = get_vehicle_info(type)

            route = combined_route[:split_ratio[curr_idx]]
            combined_route = combined_route[split_ratio[curr_idx]:]

            vehicles.append(Vehicle(
                type,
                curr_vehicle['capacity'],
                curr_vehicle['cost per km'],
                route,
                DEPOT_LOC
            ))

            curr_idx+=1

        return Solution2(vehicles)
    
    def mutate(split_ratio,combine_route):
        start, end = sorted(random.sample(range(10), 2))
        sublist = combine_route[start:end]
        random.shuffle(sublist)
        combine_route[start:end] = sublist
        
        return Solution2.create_child_sol(split_ratio,combine_route)
    
    def mate(self, solution2):
        self_split_ratio = Solution2.get_split_ratio(self.vehicles)
        self_combined_route = [customer_id for vehicle in self.vehicles for customer_id in vehicle.route]

        solution2_split_ratio = Solution2.get_split_ratio(solution2.vehicles)
        solution2_combined_route = [customer_id for vehicle in solution2.vehicles for customer_id in vehicle.route]

        prob = random.random()
        # Crossover (cross gene exchange, e.g split ratio and routes)
        if prob < 0.45: 
            # inherit split ratio from parent 1 and route from parent 2
            child_solution = Solution2.create_child_sol(self_split_ratio,solution2_combined_route)
        elif prob < 0.90: 
            # inherit split ratio from parent 2 and route from parent 1
            child_solution = Solution2.create_child_sol(solution2_split_ratio,self_combined_route)
        else:
        # Mutation (Self gene exchange)
            child_solution = Solution2.mutate(self_split_ratio,self_combined_route)

        return child_solution

# %% [markdown]
# Note:
#
# Differenece between Solution 1 and 2 is the mating algorithm, which I have tried using 2 different approaches of cross-over.
#
# Cross-over in Solution 1: Randomly choose one parent and inherit (remain) one of the vehicle route, and the route in other vehicle's route will be shuffled.
#
# Cross-over in Solution 2: Consider the route split ratio and also the sequence of the route are the available genes, then create a children that inherit one the gene from one parent and otherwise with probabilty.

# %%
# Geneate Dataset (Population)

def split_random_portion(customer_len, vehicle_len):
    random_nums = []
    curr_amount = customer_len

    for i in range(vehicle_len):
        if i+1 ==  vehicle_len:
            random_nums.append(curr_amount)
            break

        random_num = random.randint(1, curr_amount-vehicle_len+1+i)
        curr_amount-=random_num
        random_nums.append(random_num)

    return random_nums

def create_vehicle(type, route):
    info = get_vehicle_info(type)
    
    return Vehicle(
        type,
        info['capacity'],
        info['cost per km'],
        route,
        DEPOT_LOC
    )

def create_solution(solution_type):
    vehicle_type = [vehicle['type'] for vehicle in VEHICLES]
    vehicles = []

    customers_ids = [customer['id'] for customer in CUSTOMERS]
    random.shuffle(customers_ids) # shuffle customer to ensure diversity

    customers_len = len(CUSTOMERS)
    vehicles_len = len(VEHICLES)
    random_nums = split_random_portion(customers_len,vehicles_len)

    curr_idx = 0
    for type in vehicle_type:
        split_portion = random_nums[curr_idx]
        route = customers_ids[:split_portion]

        customers_ids = customers_ids[split_portion:] # remove occupied route from list

        vehicle = create_vehicle(type,route)
        vehicles.append(vehicle)
        
        curr_idx+=1

    if solution_type == 1:
        return Solution1(vehicles)
    elif solution_type == 2:
        return Solution2(vehicles)

# %%
# Create population

POPULATION_SIZE = 200

population = []

first_best_solution = None
for _ in range(POPULATION_SIZE):
    solution = create_solution(2)
    population.append(solution)
    if first_best_solution == None:
        first_best_solution = solution
    elif solution.fitness() < first_best_solution.fitness():
        first_best_solution = solution
    print(solution)
# Out:
# [{'type': 'A', 'route': [4]}, {'type': 'B', 'route': [9, 1, 8, 7]}, {'type': 'C', 'route': [3, 6, 5, 10, 2]}]
# [{'type': 'A', 'route': [8, 9, 7, 1]}, {'type': 'B', 'route': [4, 3, 6, 5]}, {'type': 'C', 'route': [2, 10]}]
# [{'type': 'A', 'route': [3, 6, 2, 10, 7, 4, 9]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [1, 5]}]
# [{'type': 'A', 'route': [3, 2]}, {'type': 'B', 'route': [6, 1, 5]}, {'type': 'C', 'route': [10, 8, 9, 4, 7]}]
# [{'type': 'A', 'route': [2, 8, 5, 7, 1]}, {'type': 'B', 'route': [9, 6, 4, 10]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [10, 8, 4]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [1, 9, 6, 7, 3, 2]}]
# [{'type': 'A', 'route': [2, 6, 1]}, {'type': 'B', 'route': [5, 7]}, {'type': 'C', 'route': [9, 3, 8, 10, 4]}]
# [{'type': 'A', 'route': [9, 1, 4, 10]}, {'type': 'B', 'route': [8, 5, 2, 3, 6]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [7, 9, 3, 10, 5, 2, 8]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [4, 6]}]
# [{'type': 'A', 'route': [8, 3]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [1, 9, 7, 10, 6, 4, 2]}]
# [{'type': 'A', 'route': [10]}, {'type': 'B', 'route': [4, 1, 5, 3, 2, 8]}, {'type': 'C', 'route': [9, 6, 7]}]
# [{'type': 'A', 'route': [7, 10, 9, 2, 5]}, {'type': 'B', 'route': [1, 4, 6, 8]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [5, 4]}, {'type': 'B', 'route': [1, 10, 9, 2, 7, 8]}, {'type': 'C', 'route': [3, 6]}]
# [{'type': 'A', 'route': [9, 4, 7, 5, 10, 3, 6, 2]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [1]}]
# [{'type': 'A', 'route': [7, 2, 8, 1, 9, 4, 10]}, {'type': 'B', 'route': [3, 6]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [3, 4, 6, 9, 5, 7]}, {'type': 'B', 'route': [1, 2, 8]}, {'type': 'C', 'route': [10]}]
# [{'type': 'A', 'route': [1]}, {'type': 'B', 'route': [10, 2, 4, 5, 8, 9, 7]}, {'type': 'C', 'route': [3, 6]}]
# [{'type': 'A', 'route': [9, 1, 5]}, {'type': 'B', 'route': [2, 6, 3]}, {'type': 'C', 'route': [7, 8, 4, 10]}]
# [{'type': 'A', 'route': [1]}, {'type': 'B', 'route': [10, 2]}, {'type': 'C', 'route': [6, 8, 9, 3, 5, 4, 7]}]
# [{'type': 'A', 'route': [6, 1, 7]}, {'type': 'B', 'route': [3, 5, 9]}, {'type': 'C', 'route': [8, 10, 4, 2]}]
# [{'type': 'A', 'route': [1, 2, 10, 5, 6]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [4, 7, 9, 3]}]
# [{'type': 'A', 'route': [2]}, {'type': 'B', 'route': [5, 7, 8, 10]}, {'type': 'C', 'route': [9, 1, 6, 3, 4]}]
# [{'type': 'A', 'route': [1, 3, 2, 9, 8, 6, 7, 5]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [5, 1, 9]}, {'type': 'B', 'route': [2, 8, 10, 4]}, {'type': 'C', 'route': [6, 3, 7]}]
# [{'type': 'A', 'route': [5, 7, 8, 6, 9, 3, 1]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [10, 2]}]
# [{'type': 'A', 'route': [7, 4]}, {'type': 'B', 'route': [1, 6]}, {'type': 'C', 'route': [2, 10, 9, 8, 3, 5]}]
# [{'type': 'A', 'route': [3]}, {'type': 'B', 'route': [10, 4]}, {'type': 'C', 'route': [8, 2, 1, 9, 7, 5, 6]}]
# [{'type': 'A', 'route': [2, 6, 10]}, {'type': 'B', 'route': [3, 9, 1, 4]}, {'type': 'C', 'route': [5, 7, 8]}]
# [{'type': 'A', 'route': [9, 8, 10, 3, 1, 2, 5, 7]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [2, 6, 8, 10, 3, 9, 5]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [1, 7]}]
# [{'type': 'A', 'route': [7, 5, 2, 6, 9, 4, 1, 10]}, {'type': 'B', 'route': [3]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [2, 3, 10, 6, 4, 9]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [7, 8, 1]}]
# [{'type': 'A', 'route': [1, 4, 3, 9, 7, 2, 5]}, {'type': 'B', 'route': [6, 8]}, {'type': 'C', 'route': [10]}]
# [{'type': 'A', 'route': [6, 7, 10, 2]}, {'type': 'B', 'route': [1, 8, 9]}, {'type': 'C', 'route': [5, 4, 3]}]
# [{'type': 'A', 'route': [2, 6]}, {'type': 'B', 'route': [5, 3, 4, 8, 10]}, {'type': 'C', 'route': [7, 1, 9]}]
# [{'type': 'A', 'route': [7, 10, 2, 1, 6]}, {'type': 'B', 'route': [8, 4, 9, 3]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [6]}, {'type': 'B', 'route': [2, 5, 3, 8, 7, 10]}, {'type': 'C', 'route': [1, 4, 9]}]
# [{'type': 'A', 'route': [1, 2, 10]}, {'type': 'B', 'route': [6, 5, 7, 9, 4, 8]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [6, 5, 9]}, {'type': 'B', 'route': [3]}, {'type': 'C', 'route': [10, 7, 4, 2, 8, 1]}]
# [{'type': 'A', 'route': [6, 7, 4, 5, 10, 3, 1, 8]}, {'type': 'B', 'route': [9]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [4, 1, 3, 8, 5, 2]}, {'type': 'B', 'route': [10, 9]}, {'type': 'C', 'route': [7, 6]}]
# [{'type': 'A', 'route': [4, 3, 1]}, {'type': 'B', 'route': [10, 5, 2, 6, 9]}, {'type': 'C', 'route': [8, 7]}]
# [{'type': 'A', 'route': [9, 3, 5, 2, 6, 10]}, {'type': 'B', 'route': [8, 7, 4]}, {'type': 'C', 'route': [1]}]
# [{'type': 'A', 'route': [8, 9, 4, 10, 3, 1, 2, 5]}, {'type': 'B', 'route': [6]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [8, 1, 6, 2, 9]}, {'type': 'B', 'route': [10, 7]}, {'type': 'C', 'route': [3, 5, 4]}]
# [{'type': 'A', 'route': [9, 8, 6, 7, 4]}, {'type': 'B', 'route': [3, 1, 5]}, {'type': 'C', 'route': [10, 2]}]
# [{'type': 'A', 'route': [1, 4, 7, 10, 3, 9, 8, 6]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [4, 2, 8, 6, 5, 7, 3]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [10, 9]}]
# [{'type': 'A', 'route': [3, 6, 5, 7, 8, 9]}, {'type': 'B', 'route': [2, 1, 10]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [7, 2, 3, 6, 4, 9, 1]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [5, 8]}]
# [{'type': 'A', 'route': [6]}, {'type': 'B', 'route': [9, 10, 1, 3, 8, 5]}, {'type': 'C', 'route': [4, 7, 2]}]
# [{'type': 'A', 'route': [2]}, {'type': 'B', 'route': [4, 5, 8, 7, 9, 6]}, {'type': 'C', 'route': [10, 3, 1]}]
# [{'type': 'A', 'route': [7, 4, 10]}, {'type': 'B', 'route': [8, 9, 6, 3, 1, 5]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [4, 6, 5, 9, 3, 10]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [2, 8, 7]}]
# [{'type': 'A', 'route': [5, 9, 6]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [4, 2, 3, 8, 1, 7]}]
# [{'type': 'A', 'route': [7, 10, 3, 9, 8, 1, 4]}, {'type': 'B', 'route': [6]}, {'type': 'C', 'route': [2, 5]}]
# [{'type': 'A', 'route': [5, 6, 9, 7]}, {'type': 'B', 'route': [10, 1, 3, 2]}, {'type': 'C', 'route': [8, 4]}]
# [{'type': 'A', 'route': [1, 6, 5, 3, 10, 8, 4]}, {'type': 'B', 'route': [2, 9]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [7, 10, 3, 5, 4]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [6, 2, 9, 8]}]
# [{'type': 'A', 'route': [9, 5, 10, 4]}, {'type': 'B', 'route': [2, 6, 3]}, {'type': 'C', 'route': [8, 7, 1]}]
# [{'type': 'A', 'route': [10, 4, 2, 9, 5, 8, 6]}, {'type': 'B', 'route': [1, 3]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [8, 4, 1, 6, 2]}, {'type': 'B', 'route': [7, 10]}, {'type': 'C', 'route': [9, 5, 3]}]
# [{'type': 'A', 'route': [4, 5, 10, 2, 6, 9, 8, 7]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [2, 10, 6]}, {'type': 'B', 'route': [1, 9, 3, 8, 5, 7]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [1, 7, 10, 4]}, {'type': 'B', 'route': [9, 8]}, {'type': 'C', 'route': [2, 6, 5, 3]}]
# [{'type': 'A', 'route': [5, 9, 3]}, {'type': 'B', 'route': [10, 6]}, {'type': 'C', 'route': [4, 8, 1, 2, 7]}]
# [{'type': 'A', 'route': [8, 2, 6, 1, 4]}, {'type': 'B', 'route': [10, 9]}, {'type': 'C', 'route': [3, 5, 7]}]
# [{'type': 'A', 'route': [3, 8, 9, 4, 6, 2, 10, 5]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [9, 4]}, {'type': 'B', 'route': [7, 6]}, {'type': 'C', 'route': [5, 2, 3, 1, 10, 8]}]
# [{'type': 'A', 'route': [4, 6, 10]}, {'type': 'B', 'route': [9, 1, 5, 8, 7]}, {'type': 'C', 'route': [3, 2]}]
# [{'type': 'A', 'route': [6, 3, 5, 9, 2, 7]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [8, 4, 1]}]
# [{'type': 'A', 'route': [10, 6, 2]}, {'type': 'B', 'route': [3, 4, 9, 8, 5]}, {'type': 'C', 'route': [7, 1]}]
# [{'type': 'A', 'route': [2, 4, 6, 1, 10, 3, 7, 5]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [6, 8, 3]}, {'type': 'B', 'route': [7, 5, 9]}, {'type': 'C', 'route': [10, 2, 1, 4]}]
# [{'type': 'A', 'route': [10, 5, 7, 6, 9, 3, 2, 8]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [8]}, {'type': 'B', 'route': [5, 7, 4, 3, 10, 2, 1, 6]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [1, 5, 9, 4]}, {'type': 'B', 'route': [8, 2, 7, 10]}, {'type': 'C', 'route': [3, 6]}]
# [{'type': 'A', 'route': [5, 9, 3, 1, 10]}, {'type': 'B', 'route': [8, 2, 6, 7]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [7, 10, 2, 1, 4, 8, 5]}, {'type': 'B', 'route': [6, 3]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [5, 10, 3, 4]}, {'type': 'B', 'route': [1, 8, 7]}, {'type': 'C', 'route': [9, 6, 2]}]
# [{'type': 'A', 'route': [2, 1, 4, 5, 3, 7]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [6, 8, 9]}]
# [{'type': 'A', 'route': [3]}, {'type': 'B', 'route': [8, 2, 7, 5]}, {'type': 'C', 'route': [1, 9, 6, 10, 4]}]
# [{'type': 'A', 'route': [4, 5, 8, 2, 10, 3]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [6, 9, 7]}]
# [{'type': 'A', 'route': [3, 7, 4, 9, 10, 2, 6, 8]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [9, 7, 1]}, {'type': 'B', 'route': [2, 3, 4, 5, 10, 6]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [2, 8, 3, 6, 9, 10]}, {'type': 'B', 'route': [4, 1]}, {'type': 'C', 'route': [5, 7]}]
# [{'type': 'A', 'route': [7, 1, 5, 8, 4, 10]}, {'type': 'B', 'route': [6]}, {'type': 'C', 'route': [2, 9, 3]}]
# [{'type': 'A', 'route': [9, 1, 10, 4, 6, 8]}, {'type': 'B', 'route': [7, 3]}, {'type': 'C', 'route': [2, 5]}]
# [{'type': 'A', 'route': [3, 1, 7, 2, 10, 9]}, {'type': 'B', 'route': [4, 5]}, {'type': 'C', 'route': [8, 6]}]
# [{'type': 'A', 'route': [2, 10, 7, 8, 9]}, {'type': 'B', 'route': [1, 6, 5]}, {'type': 'C', 'route': [3, 4]}]
# [{'type': 'A', 'route': [5, 8, 4, 7, 10, 6]}, {'type': 'B', 'route': [9, 1, 2]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [6, 9, 1, 5]}, {'type': 'B', 'route': [7, 8, 2]}, {'type': 'C', 'route': [3, 4, 10]}]
# [{'type': 'A', 'route': [4, 6, 5, 2]}, {'type': 'B', 'route': [3, 10, 1]}, {'type': 'C', 'route': [7, 9, 8]}]
# [{'type': 'A', 'route': [7, 8, 9, 2, 6, 10, 5]}, {'type': 'B', 'route': [4, 3]}, {'type': 'C', 'route': [1]}]
# [{'type': 'A', 'route': [2, 4, 7, 6, 10, 8]}, {'type': 'B', 'route': [9, 3, 1]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [8]}, {'type': 'B', 'route': [6, 1]}, {'type': 'C', 'route': [2, 10, 3, 7, 9, 5, 4]}]
# [{'type': 'A', 'route': [6, 8, 3, 10, 1]}, {'type': 'B', 'route': [7]}, {'type': 'C', 'route': [2, 9, 5, 4]}]
# [{'type': 'A', 'route': [3, 10, 4, 8, 6, 7, 5, 1]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [3, 2, 8, 7, 10]}, {'type': 'B', 'route': [5, 4, 6, 9]}, {'type': 'C', 'route': [1]}]
# [{'type': 'A', 'route': [9, 10, 4, 3]}, {'type': 'B', 'route': [7, 8, 2, 5, 1]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [9, 6, 1, 2, 5]}, {'type': 'B', 'route': [3]}, {'type': 'C', 'route': [7, 4, 10, 8]}]
# [{'type': 'A', 'route': [3, 7, 1, 9]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [5, 10, 4, 8, 6]}]
# [{'type': 'A', 'route': [5, 1]}, {'type': 'B', 'route': [4, 10, 3, 8, 6]}, {'type': 'C', 'route': [9, 2, 7]}]
# [{'type': 'A', 'route': [1, 8, 6, 10, 4, 3]}, {'type': 'B', 'route': [9]}, {'type': 'C', 'route': [2, 7, 5]}]
# [{'type': 'A', 'route': [6, 7, 9, 1, 8, 5, 2]}, {'type': 'B', 'route': [3, 10]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [4, 9, 1, 7, 2, 10, 3]}, {'type': 'B', 'route': [8, 5]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [4]}, {'type': 'B', 'route': [3, 7, 1, 10, 8]}, {'type': 'C', 'route': [2, 6, 5, 9]}]
# [{'type': 'A', 'route': [9, 8, 4, 10, 3, 2, 7, 1]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [8, 6, 9, 2, 5, 10, 7]}, {'type': 'B', 'route': [3, 1]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [1, 2]}, {'type': 'B', 'route': [10, 4, 7, 8, 5, 9, 3]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [7, 3]}, {'type': 'B', 'route': [6, 1, 2, 8, 5, 4]}, {'type': 'C', 'route': [10, 9]}]
# [{'type': 'A', 'route': [8, 7, 5, 1, 2, 9, 3, 10]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [6]}]
# [{'type': 'A', 'route': [2, 3, 8]}, {'type': 'B', 'route': [7, 9, 10]}, {'type': 'C', 'route': [5, 4, 6, 1]}]
# [{'type': 'A', 'route': [7, 5, 4]}, {'type': 'B', 'route': [2, 1, 8, 3]}, {'type': 'C', 'route': [6, 10, 9]}]
# [{'type': 'A', 'route': [6, 1, 2]}, {'type': 'B', 'route': [3, 10, 4, 9, 8]}, {'type': 'C', 'route': [7, 5]}]
# [{'type': 'A', 'route': [7, 3, 4, 1, 2, 8]}, {'type': 'B', 'route': [9, 6]}, {'type': 'C', 'route': [10, 5]}]
# [{'type': 'A', 'route': [3]}, {'type': 'B', 'route': [8, 2, 7, 6, 1, 4, 5, 10]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [3, 1, 7, 2, 6]}, {'type': 'B', 'route': [10, 5, 9]}, {'type': 'C', 'route': [8, 4]}]
# [{'type': 'A', 'route': [3, 4, 6, 2, 1, 7, 10, 9]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [5, 10, 1, 9, 3, 4]}, {'type': 'B', 'route': [8, 6]}, {'type': 'C', 'route': [2, 7]}]
# [{'type': 'A', 'route': [10, 8, 1, 5, 9, 6, 3, 4]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [2, 5, 10, 7, 9]}, {'type': 'B', 'route': [4, 6]}, {'type': 'C', 'route': [8, 1, 3]}]
# [{'type': 'A', 'route': [5]}, {'type': 'B', 'route': [4, 6, 7, 3]}, {'type': 'C', 'route': [9, 10, 8, 2, 1]}]
# [{'type': 'A', 'route': [4, 9, 3]}, {'type': 'B', 'route': [10, 1, 8, 2, 7]}, {'type': 'C', 'route': [5, 6]}]
# [{'type': 'A', 'route': [6, 5, 2, 9, 4, 1]}, {'type': 'B', 'route': [7, 8, 10]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [10, 7, 5, 6, 3, 8]}, {'type': 'B', 'route': [4, 1, 9]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [2, 6, 5, 7, 4, 9, 3]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [1, 10]}]
# [{'type': 'A', 'route': [9, 2, 6, 8, 10, 7, 1, 3]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [3, 7, 9, 2]}, {'type': 'B', 'route': [5, 6, 10]}, {'type': 'C', 'route': [4, 8, 1]}]
# [{'type': 'A', 'route': [5, 6, 3, 10, 4, 7, 9, 1]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [9, 7, 3]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [2, 10, 4, 8, 5, 6]}]
# [{'type': 'A', 'route': [3, 5, 1, 9, 8, 6, 4, 2]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [3, 6, 2, 5, 4, 8, 9]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [1, 7]}]
# [{'type': 'A', 'route': [7, 8, 5, 2, 3, 9, 6, 1]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [10]}]
# [{'type': 'A', 'route': [7, 10]}, {'type': 'B', 'route': [4, 8, 3]}, {'type': 'C', 'route': [5, 1, 9, 6, 2]}]
# [{'type': 'A', 'route': [1, 10, 2, 6, 9]}, {'type': 'B', 'route': [5, 3]}, {'type': 'C', 'route': [4, 8, 7]}]
# [{'type': 'A', 'route': [9, 3, 1]}, {'type': 'B', 'route': [5, 2, 6, 4, 10, 8]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [4, 10, 8, 6]}, {'type': 'B', 'route': [2, 1, 5]}, {'type': 'C', 'route': [3, 9, 7]}]
# [{'type': 'A', 'route': [5, 3, 6, 2, 9, 8]}, {'type': 'B', 'route': [1, 4]}, {'type': 'C', 'route': [7, 10]}]
# [{'type': 'A', 'route': [7, 3, 5]}, {'type': 'B', 'route': [9, 2, 10]}, {'type': 'C', 'route': [4, 8, 1, 6]}]
# [{'type': 'A', 'route': [7, 4, 10]}, {'type': 'B', 'route': [9]}, {'type': 'C', 'route': [1, 3, 8, 6, 2, 5]}]
# [{'type': 'A', 'route': [9, 7, 3, 8, 4, 6]}, {'type': 'B', 'route': [10, 5, 1]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [6]}, {'type': 'B', 'route': [1, 9, 3, 5, 8, 2]}, {'type': 'C', 'route': [7, 4, 10]}]
# [{'type': 'A', 'route': [6, 2, 5, 1, 9, 10, 3, 8]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [1, 10, 2, 3, 8]}, {'type': 'B', 'route': [4, 9, 6]}, {'type': 'C', 'route': [5, 7]}]
# [{'type': 'A', 'route': [4, 3, 2, 9]}, {'type': 'B', 'route': [6, 5, 1, 10]}, {'type': 'C', 'route': [8, 7]}]
# [{'type': 'A', 'route': [4, 2]}, {'type': 'B', 'route': [6, 8]}, {'type': 'C', 'route': [1, 9, 10, 7, 5, 3]}]
# [{'type': 'A', 'route': [1, 2]}, {'type': 'B', 'route': [10, 9, 8, 6]}, {'type': 'C', 'route': [7, 4, 5, 3]}]
# [{'type': 'A', 'route': [7]}, {'type': 'B', 'route': [10, 9, 4, 8, 2, 6]}, {'type': 'C', 'route': [3, 1, 5]}]
# [{'type': 'A', 'route': [2, 7, 6, 1, 3]}, {'type': 'B', 'route': [4, 5, 8, 9]}, {'type': 'C', 'route': [10]}]
# [{'type': 'A', 'route': [6]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [3, 1, 9, 8, 2, 10, 5, 7]}]
# [{'type': 'A', 'route': [1, 2, 3, 7, 4, 5]}, {'type': 'B', 'route': [10, 9, 6]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [10, 7, 3, 4]}, {'type': 'B', 'route': [1, 8, 5, 9, 6]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [9, 10, 6, 3, 4, 5, 1]}, {'type': 'B', 'route': [8, 2]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [1, 10, 9, 2, 7]}, {'type': 'B', 'route': [6, 4]}, {'type': 'C', 'route': [8, 3, 5]}]
# [{'type': 'A', 'route': [10]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [8, 2, 3, 7, 4, 1, 9, 6]}]
# [{'type': 'A', 'route': [4, 1, 8, 6, 2, 7, 3, 10]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [5]}, {'type': 'B', 'route': [7, 2, 6, 9]}, {'type': 'C', 'route': [8, 1, 3, 4, 10]}]
# [{'type': 'A', 'route': [5, 4, 2, 10, 1, 3, 8, 6]}, {'type': 'B', 'route': [9]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [9, 3, 2, 6, 7, 4, 1, 5]}, {'type': 'B', 'route': [10]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [10]}, {'type': 'B', 'route': [4]}, {'type': 'C', 'route': [1, 7, 2, 9, 3, 8, 5, 6]}]
# [{'type': 'A', 'route': [3]}, {'type': 'B', 'route': [5, 10, 6, 4, 1, 7]}, {'type': 'C', 'route': [2, 9, 8]}]
# [{'type': 'A', 'route': [10]}, {'type': 'B', 'route': [5, 8, 9, 2]}, {'type': 'C', 'route': [6, 1, 4, 7, 3]}]
# [{'type': 'A', 'route': [8, 3, 7, 10, 4, 1, 2]}, {'type': 'B', 'route': [9]}, {'type': 'C', 'route': [5, 6]}]
# [{'type': 'A', 'route': [3, 7, 4, 5, 1, 6, 9, 10]}, {'type': 'B', 'route': [2]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [8, 7, 6, 5, 1, 9, 3]}, {'type': 'B', 'route': [4, 10]}, {'type': 'C', 'route': [2]}]
# [{'type': 'A', 'route': [9]}, {'type': 'B', 'route': [5, 1, 4, 8, 10]}, {'type': 'C', 'route': [2, 6, 3, 7]}]
# [{'type': 'A', 'route': [4, 9]}, {'type': 'B', 'route': [8, 7, 1, 10, 3, 5]}, {'type': 'C', 'route': [2, 6]}]
# [{'type': 'A', 'route': [4, 7, 6, 5]}, {'type': 'B', 'route': [10, 2, 9]}, {'type': 'C', 'route': [8, 3, 1]}]
# [{'type': 'A', 'route': [5, 8, 7, 4, 2, 6, 3]}, {'type': 'B', 'route': [10, 1]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [5, 10, 2]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [6, 3, 4, 7, 8, 9]}]
# [{'type': 'A', 'route': [2, 1, 4]}, {'type': 'B', 'route': [8, 5, 9, 10, 3]}, {'type': 'C', 'route': [7, 6]}]
# [{'type': 'A', 'route': [7]}, {'type': 'B', 'route': [10, 6, 2, 9, 4, 5, 8]}, {'type': 'C', 'route': [3, 1]}]
# [{'type': 'A', 'route': [5, 1, 3, 7, 10]}, {'type': 'B', 'route': [2, 6, 9]}, {'type': 'C', 'route': [8, 4]}]
# [{'type': 'A', 'route': [2, 7, 8]}, {'type': 'B', 'route': [1, 10, 6, 4, 9, 3]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [7, 3, 2, 5, 9]}, {'type': 'B', 'route': [1, 10, 8]}, {'type': 'C', 'route': [4, 6]}]
# [{'type': 'A', 'route': [2]}, {'type': 'B', 'route': [5]}, {'type': 'C', 'route': [8, 9, 3, 7, 1, 10, 6, 4]}]
# [{'type': 'A', 'route': [2, 7]}, {'type': 'B', 'route': [3, 9, 1, 4, 6, 10]}, {'type': 'C', 'route': [8, 5]}]
# [{'type': 'A', 'route': [5, 6, 3]}, {'type': 'B', 'route': [10, 2, 4, 1, 8, 9]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [3, 4, 7, 9]}, {'type': 'B', 'route': [10, 1, 6, 5]}, {'type': 'C', 'route': [2, 8]}]
# [{'type': 'A', 'route': [7, 5, 2, 8]}, {'type': 'B', 'route': [4, 10]}, {'type': 'C', 'route': [1, 9, 6, 3]}]
# [{'type': 'A', 'route': [9, 6, 2, 10, 8, 5]}, {'type': 'B', 'route': [1, 4, 3]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [5, 4, 7, 2]}, {'type': 'B', 'route': [10, 6, 8]}, {'type': 'C', 'route': [3, 1, 9]}]
# [{'type': 'A', 'route': [10]}, {'type': 'B', 'route': [7, 8]}, {'type': 'C', 'route': [9, 2, 1, 4, 6, 3, 5]}]
# [{'type': 'A', 'route': [10, 9, 5, 3]}, {'type': 'B', 'route': [6, 4, 7, 1]}, {'type': 'C', 'route': [8, 2]}]
# [{'type': 'A', 'route': [7]}, {'type': 'B', 'route': [1, 4, 9, 3, 6, 2, 8, 10]}, {'type': 'C', 'route': [5]}]
# [{'type': 'A', 'route': [3, 8, 2, 5, 6, 4]}, {'type': 'B', 'route': [1, 10, 9]}, {'type': 'C', 'route': [7]}]
# [{'type': 'A', 'route': [6, 2, 9, 3, 1, 5]}, {'type': 'B', 'route': [4, 10, 7]}, {'type': 'C', 'route': [8]}]
# [{'type': 'A', 'route': [9, 1, 4, 3]}, {'type': 'B', 'route': [5, 2, 8, 6, 7]}, {'type': 'C', 'route': [10]}]
# [{'type': 'A', 'route': [10, 9, 2]}, {'type': 'B', 'route': [5, 3]}, {'type': 'C', 'route': [6, 1, 4, 7, 8]}]
# [{'type': 'A', 'route': [10, 3]}, {'type': 'B', 'route': [1, 7, 9, 6, 5, 2]}, {'type': 'C', 'route': [4, 8]}]
# [{'type': 'A', 'route': [5, 4, 10, 9]}, {'type': 'B', 'route': [1, 7, 2, 8, 6]}, {'type': 'C', 'route': [3]}]
# [{'type': 'A', 'route': [6, 1, 5, 7, 4, 10, 2, 3]}, {'type': 'B', 'route': [8]}, {'type': 'C', 'route': [9]}]
# [{'type': 'A', 'route': [2, 8]}, {'type': 'B', 'route': [3, 9, 5, 7]}, {'type': 'C', 'route': [4, 6, 1, 10]}]
# [{'type': 'A', 'route': [3, 7, 5]}, {'type': 'B', 'route': [8, 10, 6]}, {'type': 'C', 'route': [4, 9, 1, 2]}]
# [{'type': 'A', 'route': [8, 5, 7, 10, 3]}, {'type': 'B', 'route': [2, 9, 6, 1]}, {'type': 'C', 'route': [4]}]
# [{'type': 'A', 'route': [3, 10, 5]}, {'type': 'B', 'route': [1]}, {'type': 'C', 'route': [7, 2, 9, 6, 4, 8]}]
# [{'type': 'A', 'route': [3, 7]}, {'type': 'B', 'route': [4, 2]}, {'type': 'C', 'route': [8, 6, 9, 1, 5, 10]}]
# [{'type': 'A', 'route': [9, 2]}, {'type': 'B', 'route': [1, 5]}, {'type': 'C', 'route': [3, 4, 7, 8, 6, 10]}]
# [{'type': 'A', 'route': [8, 5, 4, 6, 3]}, {'type': 'B', 'route': [10, 1, 2]}, {'type': 'C', 'route': [9, 7]}]

# %%
print("\n<<<< BEST SOLUTION (First Generated Population)>>>>\n")

first_best_solution.print()
# Out:
# <<<< BEST SOLUTION (First Generated Population)>>>>
#
# Total Distance: 127.47KM
# Total cost: RM167.73
#
#
# Vehicle A:
# Round Trip Distance: 45.80 KM, Cost: RM54.96, Demand: 17, Capacity: 25
# Depot -> 2 (9.07 KM) -> 3 (10.83 KM) -> 8 (14.29 KM) -> Depot (11.61 KM)
#
#
# Vehicle B:
# Round Trip Distance: 33.02 KM, Cost: RM49.52, Demand: 16, Capacity: 30
# Depot -> 7 (6.51 KM) -> 9 (12.01 KM) -> 10 (6.06 KM) -> Depot (8.44 KM)
#
#
# Vehicle C:
# Round Trip Distance: 48.65 KM, Cost: RM63.25, Demand: 24, Capacity: 27
# Depot -> 5 (10.48 KM) -> 4 (8.41 KM) -> 6 (9.78 KM) -> 1 (6.83 KM) -> Depot (13.15 KM)

# %%
# define task function to run GA algo

GENERATION_SIZE = 10

def task(id):
    global population

    population_copy = population.copy()

    for i in range(GENERATION_SIZE):
        population_copy = sorted(population_copy, key = lambda solution:solution.fitness())
        new_generation = []

        # include 10% of the fittest solution in the next generation
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population_copy[:s])

        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            # only consider choosing among 50% fittest solution as parents,
            # to produce offsprings
            parent1 = random.choice(population_copy[:int(POPULATION_SIZE/2)])
            parent2 = random.choice(population_copy[:int(POPULATION_SIZE/2)])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population_copy = new_generation

        #print(f"Generation {i+1}: Best fitness score (Lowest Total Cost) - RM {(population_copy[0].fitness()):.2f}")

    #print_sol_info(population[0],GENERATION_SIZE)
    print(f"[Task {id+1}] Best fitness score (Lowest Total Cost) - RM {(population_copy[0].fitness()):.2f}")

    return population_copy[0]

# %%
# Kinda simulate multi Threading
# Where n number of GAs will run simultaneously, to find the best out of the best
best_solution = None
for i in range(100):
    solution = task(i)
    if best_solution == None:
        best_solution = solution
    elif solution.fitness() < best_solution.fitness():
        best_solution = solution

print(f"\n<<<< BEST SOLUTION (Out of {i+1} Tasks)>>>>\n")

best_solution.print()
# Out:
# [Task 1] Best fitness score (Lowest Total Cost) - RM 133.71
# [Task 2] Best fitness score (Lowest Total Cost) - RM 141.67
# [Task 3] Best fitness score (Lowest Total Cost) - RM 149.82
# [Task 4] Best fitness score (Lowest Total Cost) - RM 153.97
# [Task 5] Best fitness score (Lowest Total Cost) - RM 143.22
# [Task 6] Best fitness score (Lowest Total Cost) - RM 142.13
# [Task 7] Best fitness score (Lowest Total Cost) - RM 152.85
# [Task 8] Best fitness score (Lowest Total Cost) - RM 149.44
# [Task 9] Best fitness score (Lowest Total Cost) - RM 154.54
# [Task 10] Best fitness score (Lowest Total Cost) - RM 147.89
# [Task 11] Best fitness score (Lowest Total Cost) - RM 132.34
# [Task 12] Best fitness score (Lowest Total Cost) - RM 143.22
# [Task 13] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 14] Best fitness score (Lowest Total Cost) - RM 149.61
# [Task 15] Best fitness score (Lowest Total Cost) - RM 132.04
# [Task 16] Best fitness score (Lowest Total Cost) - RM 136.97
# [Task 17] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 18] Best fitness score (Lowest Total Cost) - RM 151.43
# [Task 19] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 20] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 21] Best fitness score (Lowest Total Cost) - RM 144.99
# [Task 22] Best fitness score (Lowest Total Cost) - RM 144.32
# [Task 23] Best fitness score (Lowest Total Cost) - RM 145.78
# [Task 24] Best fitness score (Lowest Total Cost) - RM 153.97
# [Task 25] Best fitness score (Lowest Total Cost) - RM 148.39
# [Task 26] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 27] Best fitness score (Lowest Total Cost) - RM 148.45
# [Task 28] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 29] Best fitness score (Lowest Total Cost) - RM 151.00
# [Task 30] Best fitness score (Lowest Total Cost) - RM 139.79
# [Task 31] Best fitness score (Lowest Total Cost) - RM 149.98
# [Task 32] Best fitness score (Lowest Total Cost) - RM 142.13
# [Task 33] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 34] Best fitness score (Lowest Total Cost) - RM 143.21
# [Task 35] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 36] Best fitness score (Lowest Total Cost) - RM 145.49
# [Task 37] Best fitness score (Lowest Total Cost) - RM 149.45
# [Task 38] Best fitness score (Lowest Total Cost) - RM 152.88
# [Task 39] Best fitness score (Lowest Total Cost) - RM 148.20
# [Task 40] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 41] Best fitness score (Lowest Total Cost) - RM 152.80
# [Task 42] Best fitness score (Lowest Total Cost) - RM 149.89
# [Task 43] Best fitness score (Lowest Total Cost) - RM 155.44
# [Task 44] Best fitness score (Lowest Total Cost) - RM 148.72
# [Task 45] Best fitness score (Lowest Total Cost) - RM 150.19
# [Task 46] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 47] Best fitness score (Lowest Total Cost) - RM 148.00
# [Task 48] Best fitness score (Lowest Total Cost) - RM 148.45
# [Task 49] Best fitness score (Lowest Total Cost) - RM 137.97
# [Task 50] Best fitness score (Lowest Total Cost) - RM 143.03
# [Task 51] Best fitness score (Lowest Total Cost) - RM 150.79
# [Task 52] Best fitness score (Lowest Total Cost) - RM 151.76
# [Task 53] Best fitness score (Lowest Total Cost) - RM 142.07
# [Task 54] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 55] Best fitness score (Lowest Total Cost) - RM 153.38
# [Task 56] Best fitness score (Lowest Total Cost) - RM 138.72
# [Task 57] Best fitness score (Lowest Total Cost) - RM 150.62
# [Task 58] Best fitness score (Lowest Total Cost) - RM 143.02
# [Task 59] Best fitness score (Lowest Total Cost) - RM 152.85
# [Task 60] Best fitness score (Lowest Total Cost) - RM 148.14
# [Task 61] Best fitness score (Lowest Total Cost) - RM 153.63
# [Task 62] Best fitness score (Lowest Total Cost) - RM 146.82
# [Task 63] Best fitness score (Lowest Total Cost) - RM 144.96
# [Task 64] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 65] Best fitness score (Lowest Total Cost) - RM 151.00
# [Task 66] Best fitness score (Lowest Total Cost) - RM 153.97
# [Task 67] Best fitness score (Lowest Total Cost) - RM 150.41
# [Task 68] Best fitness score (Lowest Total Cost) - RM 146.60
# [Task 69] Best fitness score (Lowest Total Cost) - RM 151.00
# [Task 70] Best fitness score (Lowest Total Cost) - RM 144.02
# [Task 71] Best fitness score (Lowest Total Cost) - RM 147.45
# [Task 72] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 73] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 74] Best fitness score (Lowest Total Cost) - RM 150.07
# [Task 75] Best fitness score (Lowest Total Cost) - RM 151.43
# [Task 76] Best fitness score (Lowest Total Cost) - RM 155.44
# [Task 77] Best fitness score (Lowest Total Cost) - RM 148.00
# [Task 78] Best fitness score (Lowest Total Cost) - RM 149.45
# [Task 79] Best fitness score (Lowest Total Cost) - RM 154.74
# [Task 80] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 81] Best fitness score (Lowest Total Cost) - RM 149.24
# [Task 82] Best fitness score (Lowest Total Cost) - RM 149.46
# [Task 83] Best fitness score (Lowest Total Cost) - RM 147.34
# [Task 84] Best fitness score (Lowest Total Cost) - RM 150.35
# [Task 85] Best fitness score (Lowest Total Cost) - RM 153.97
# [Task 86] Best fitness score (Lowest Total Cost) - RM 151.59
# [Task 87] Best fitness score (Lowest Total Cost) - RM 148.00
# [Task 88] Best fitness score (Lowest Total Cost) - RM 149.76
# [Task 89] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 90] Best fitness score (Lowest Total Cost) - RM 144.95
# [Task 91] Best fitness score (Lowest Total Cost) - RM 142.00
# [Task 92] Best fitness score (Lowest Total Cost) - RM 151.00
# [Task 93] Best fitness score (Lowest Total Cost) - RM 151.31
# [Task 94] Best fitness score (Lowest Total Cost) - RM 150.79
# [Task 95] Best fitness score (Lowest Total Cost) - RM 150.03
# [Task 96] Best fitness score (Lowest Total Cost) - RM 146.60
# [Task 97] Best fitness score (Lowest Total Cost) - RM 153.97
# [Task 98] Best fitness score (Lowest Total Cost) - RM 151.71
# [Task 99] Best fitness score (Lowest Total Cost) - RM 153.50
# [Task 100] Best fitness score (Lowest Total Cost) - RM 151.43
#
# <<<< BEST SOLUTION (Out of 100 Tasks)>>>>
#
# Total Distance: 99.24KM
# Total cost: RM132.04
#
#
# Vehicle A:
# Round Trip Distance: 41.42 KM, Cost: RM49.70, Demand: 22, Capacity: 25
# Depot -> 7 (6.51 KM) -> 10 (6.02 KM) -> 9 (6.06 KM) -> 8 (11.22 KM) -> Depot (11.61 KM)
#
#
# Vehicle B:
# Round Trip Distance: 35.84 KM, Cost: RM53.76, Demand: 14, Capacity: 30
# Depot -> 3 (10.35 KM) -> 4 (8.32 KM) -> 1 (4.02 KM) -> Depot (13.15 KM)
#
#
# Vehicle C:
# Round Trip Distance: 21.98 KM, Cost: RM28.58, Demand: 21, Capacity: 27
# Depot -> 6 (8.06 KM) -> 2 (1.83 KM) -> 5 (1.60 KM) -> Depot (10.48 KM)

# %%
# This is task function that apply a while loop to find the best solution of a cost threshold

GENERATION_SIZE = 1000
COST_THRESHOLD = 120

def task():
    global population

    population_copy = population.copy()

    lowest_cost_solution = None

    curr_idx = 0
    while True:
        population_copy = sorted(population_copy, key = lambda solution:solution.fitness())
        new_generation = []

        # include 10% of the fittest solution in the next generation
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population_copy[:s])

        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            # only consider choosing among 50% fittest solution as parents,
            # to produce offsprings
            parent1 = random.choice(population_copy[:int(POPULATION_SIZE/2)])
            parent2 = random.choice(population_copy[:int(POPULATION_SIZE/2)])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population_copy = new_generation

        lowest_cost_solution = population_copy[0]

        print(f"Generation {curr_idx+1}: Best fitness score (Lowest Total Cost) - RM {(lowest_cost_solution.fitness()):.2f}")
        curr_idx+=1

        if lowest_cost_solution.fitness() <= COST_THRESHOLD:
            break 

    #print_sol_info(population[0],GENERATION_SIZE)

task()

# %% [markdown]
# Note: this function is not suitable due to the tasks generated might greater than the threshold infinitely, hence, cant terminate
